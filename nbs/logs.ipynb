# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(1, figsize=(12, 8))


#
data = pd.read_csv("../logs/training_dataset_60k_window20k_L4_scaling3_diff.log", header=None)
data.columns = ["phase", "epoch", "loss"]
train = data[data['phase'] == 'train']
test = data[data['phase'] == 'test']
sns.lineplot(data=train , x=range(train.shape[0]), y="loss", label=f"training_dataset_60k_window20k_L4 (train)", linestyle="-")

data = pd.read_csv("../logs/training_dataset_60k_window20k_L4_scaling3_diff.log", header=None)
data.columns = ["phase", "epoch", "loss"]
train = data[data['phase'] == 'train']
test = data[data['phase'] == 'test']
sns.lineplot(data=test , x=range(test.shape[0]), y="loss", label=f"training_dataset_60k_window20k_L4 (test)", linestyle="--")



plt.grid(True)
plt.ylim(0.2, 0.45)
plt.xlim(0, 50)
plt.xlabel("Epochs")
plt.ylabel("Loss")

#plt.savefig("losses_train.png", dpi=300)
# Out:
# Text(0, 0.5, 'Loss')
